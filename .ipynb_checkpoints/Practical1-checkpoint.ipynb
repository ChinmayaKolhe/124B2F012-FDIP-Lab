# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt


img = cv2.imread('nature.jpg', cv2.IMREAD_GRAYSCALE)
if img is None:
    raise ValueError("Image not found or path is incorrect")


def brighten(image, value=50):
    return cv2.convertScaleAbs(image, alpha=1, beta=value)


def darken(image, value=50):
    return cv2.convertScaleAbs(image, alpha=1, beta=-value)


def threshold(image, thresh_val=128):
    _, thresh_img = cv2.threshold(image, thresh_val, 255, cv2.THRESH_BINARY)
    return thresh_img


def negative(image):
    return 255 - image


def log_transform(image):
    c = 255 / (np.log(1 + np.max(image)))
    log_image = c * (np.log(image + 1))
    return np.array(log_image, dtype=np.uint8)


def power_law_transform(image, gamma=0.5):
    normalized_img = image / 255.0
    power_img = np.power(normalized_img, gamma)
    result = np.uint8(power_img * 255)
    return result


bright_img = brighten(img, 50)
dark_img = darken(img, 50)
thresh_img = threshold(img, 128)
negative_img = negative(img)
log_img = log_transform(img)
power_img = power_law_transform(img, gamma=0.5)


titles = ['Original', 'Brightened', 'Darkened', 'Thresholded', 'Negative', 'Log Transform', 'Power Law Transform']
images = [img, bright_img, dark_img, thresh_img, negative_img, log_img, power_img]

plt.figure(figsize=(15,8))
for i in range(len(images)):
    plt.subplot(2,4,i+1)
    plt.imshow(images[i], cmap='gray')
    plt.title(titles[i])
    plt.axis('off')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Pccoe\AppData\Local\Temp\ipykernel_15800\925238325.py:30: RuntimeWarning: divide by zero encountered in log
#   log_image = c * (np.log(image + 1))
# C:\Users\Pccoe\AppData\Local\Temp\ipykernel_15800\925238325.py:31: RuntimeWarning: invalid value encountered in cast
#   return np.array(log_image, dtype=np.uint8)
