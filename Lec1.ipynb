# %%
import numpy as np
import matplotlib.pyplot as plt
from skimage import img_as_uint
from skimage.io import imshow, imread
from skimage.color import rgb2hsv, rgb2gray

# %%
array_1 = np.array([[255, 0], [0, 255]])
imshow(array_1, cmap='gray')
# Out:
# C:\Users\Pccoe\AppData\Local\Temp\ipykernel_12764\4236683106.py:2: FutureWarning: `imshow` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   imshow(array_1, cmap='gray')
# C:\Users\Pccoe\anaconda3\anac\Lib\site-packages\skimage\io\_plugins\matplotlib_plugin.py:158: UserWarning: Low image data range; displaying image with stretched contrast.
#   lo, hi, cmap = _get_display_range(image)

# %%
array_2 = np.array([[255, 0, 255], [0, 255, 0], [255, 0, 255]])
imshow(array_2, cmap='gray')
# Out:
# C:\Users\Pccoe\AppData\Local\Temp\ipykernel_12764\2676530775.py:2: FutureWarning: `imshow` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   imshow(array_2, cmap='gray')
# C:\Users\Pccoe\anaconda3\anac\Lib\site-packages\skimage\io\_plugins\matplotlib_plugin.py:158: UserWarning: Low image data range; displaying image with stretched contrast.
#   lo, hi, cmap = _get_display_range(image)

# %%
array_spectrum = np.array([
    np.arange(0, 255, 17),
    np.arange(255, 0, -17),
    np.arange(0, 255, 17),
    np.arange(255, 0, -17)
])

fig, ax = plt.subplots(1, 2, figsize=(12, 4))
ax[0].imshow(array_spectrum, cmap='gray')
ax[0].set_title('Arange Generation')
ax[1].imshow(array_spectrum.T, cmap='gray')
ax[1].set_title('Transpose Generation')
# Out:
# Text(0.5, 1.0, 'Transpose Generation')

# %%
array_colors = np.array([[[255, 0, 0], [0, 255, 0], [0, 0, 255]]])
imshow(array_colors)
# Out:
# C:\Users\Pccoe\AppData\Local\Temp\ipykernel_12764\2257095743.py:2: FutureWarning: `imshow` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   imshow(array_colors)
# C:\Users\Pccoe\anaconda3\anac\Lib\site-packages\skimage\io\_plugins\matplotlib_plugin.py:158: UserWarning: Low image data range; displaying image with stretched contrast.
#   lo, hi, cmap = _get_display_range(image)

# %%
doggo = imread('nature.jpg')
imshow(doggo)
# Out:
# C:\Users\Pccoe\AppData\Local\Temp\ipykernel_12764\34742405.py:2: FutureWarning: `imshow` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   imshow(doggo)

# %%
doggo.shape
# Out:
# (384, 612, 3)

# %%
fig, ax = plt.subplots(1, 3, figsize=(6, 4), sharey=True)
ax[0].imshow(doggo[:, 0:130])
ax[0].set_title('First Split')
ax[1].imshow(doggo[:, 130:260])
ax[1].set_title('Second Split')
ax[2].imshow(doggo[:, 260:390])
ax[2].set_title('Third Split')
# Out:
# Text(0.5, 1.0, 'Third Split')

# %%
imshow(doggo[95:250, 130:275])
# Out:
# C:\Users\Pccoe\AppData\Local\Temp\ipykernel_12764\4213978428.py:1: FutureWarning: `imshow` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   imshow(doggo[95:250, 130:275])

# %%
fig, ax = plt.subplots(1, 3, figsize=(12, 4), sharey=True)
ax[0].imshow(doggo[:, :, 0], cmap='Reds')
ax[0].set_title('Red')
ax[1].imshow(doggo[:, :, 1], cmap='Greens')
ax[1].set_title('Green')
ax[2].imshow(doggo[:, :, 2], cmap='Blues')
ax[2].set_title('Blue')
# Out:
# Text(0.5, 1.0, 'Blue')

# %%
doggo_hsv = rgb2hsv(doggo)
fig, ax = plt.subplots(1, 3, figsize=(12, 4), sharey=True)
ax[0].imshow(doggo_hsv[:, :, 0], cmap='hsv')
ax[0].set_title('Hue')
ax[1].imshow(doggo_hsv[:, :, 1], cmap='gray')
ax[1].set_title('Saturation')
ax[2].imshow(doggo_hsv[:, :, 2], cmap='gray')
ax[2].set_title('Value')
# Out:
# Text(0.5, 1.0, 'Value')

# %%
doggo_gray = rgb2gray(doggo)
fig, ax = plt.subplots(1, 5, figsize=(17, 6), sharey=True)

ax[0].imshow(doggo_gray, cmap='gray')
ax[0].set_title('Grayscale Original')

ax[1].imshow(img_as_uint(doggo_gray > 0.25), cmap='gray')
ax[1].set_title('Greater than 0.25')

ax[2].imshow(img_as_uint(doggo_gray > 0.50), cmap='gray')
ax[2].set_title('Greater than 0.50')

ax[3].imshow(img_as_uint(doggo_gray > 0.75), cmap='gray')
ax[3].set_title('Greater than 0.75')

ax[4].imshow(img_as_uint(doggo_gray > np.mean(doggo_gray)), cmap='gray')
ax[4].set_title('Greater than Mean')
# Out:
# Text(0.5, 1.0, 'Greater than Mean')
